# %%
import pickle
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

DIR_REPO = Path.cwd().parents[2]
if str(DIR_REPO) not in sys.path:
    sys.path.insert(0, str(DIR_REPO))
print(DIR_REPO)
# Out:
# /home/nnovikov/repo/sim_data_analyzer

# %%
DIRPATH_CACHE = DIR_REPO / 'dev_scratch' / 'data_proc' / 'grid_5x5_thal'

fpath_rates = DIRPATH_CACHE / 'batch_rates__source-pkl__var-rates__pops-no-frz__dt-5ms__tau-20ms__lazy.nc'
R = xr.open_dataarray(fpath_rates)
R
# Out:
# <xarray.DataArray (rxe: 5, rxi: 5, pop: 4, time: 800)> Size: 640kB
# [80000 values with dtype=float64]
# Coordinates:
#   * rxe      (rxe) float64 40B 1.0 3.751e+03 7.5e+03 1.125e+04 1.5e+04
#   * rxi      (rxi) float64 40B 1.0 375.8 750.5 1.125e+03 1.5e+03
#   * pop      (pop) <U4 64B 'TI' 'TIM' 'IRE' 'IREM'
#   * time     (time) float64 6kB 1.0 1.005 1.01 1.015 ... 4.98 4.985 4.99 4.995
#     job_id   (rxe, rxi) int64 200B ...
# Attributes:
#     cache_info:  __json__:{"cache_id":"c08bb3a32c95","cache_version":1,"param...
#     proc_steps:  __json__:[{"name":"collect_batch_rates_from_pkl","params":{"...

# %%
rr = R.sel(pop='TI').isel(rxe=3, rxi=2).compute()
#rr

rr.plot()
